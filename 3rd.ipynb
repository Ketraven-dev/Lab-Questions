# %%
from random import *
marks = []
for i in range(1, 31):
    marks.append(randint(0, 100))
print("Marks of 30 students:")
print(marks)
# Out:
# Marks of 30 students:
# [10, 97, 11, 89, 81, 82, 80, 65, 1, 18, 19, 12, 56, 2, 93, 9, 18, 38, 70, 53, 70, 81, 38, 79, 68, 44, 59, 42, 79, 78]
